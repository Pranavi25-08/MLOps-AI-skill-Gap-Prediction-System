# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranavi25-08/MLOps-AI-skill-Gap-Prediction-System/blob/main/MLOpslab3employable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Upload Excel file
from google.colab import files

uploaded = files.upload()

# Load dataset
file_name = list(uploaded.keys())[0]
df = pd.read_excel(file_name)

print("Dataset loaded successfully!")
print("Shape:", df.shape)

df.head()
# Out:
#      <input type="file" id="files-c8f13fc7-f410-4165-9002-8d5256079699" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c8f13fc7-f410-4165-9002-8d5256079699">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Display column names
print("Columns:")
print(df.columns.tolist())

# Dataset information
print("\nDataset Information:")
df.info()

# Statistical summary
print("\nStatistical Summary:")
display(df.describe())

# Check missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Check duplicate rows
print("\nDuplicate rows:", df.duplicated().sum())
# Out:
# Columns:
# ['Student_ID', 'Persona', 'Age', 'Gender', 'CGPA', 'Attendance', 'Python', 'Java', 'C++', 'SQL', 'JavaScript', 'HTML_CSS', 'React', 'NodeJS', 'Git', 'Docker', 'AWS', 'Linux', 'MachineLearning', 'DeepLearning', 'DataAnalysis', 'Projects', 'Internship', 'Certifications', 'Hackathons', 'OpenSource_PRs', 'DSA_Score', 'Aptitude', 'Communication', 'ProblemSolving', 'Resume_ATS', 'Resume_Match', 'Skill_Match', 'Missing_Skills', 'Industry_Demand', 'Employable']
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 36 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Student_ID       1200 non-null   int64
#  1   Persona          1200 non-null   object
#  2   Age              1200 non-null   int64
#  3   Gender           1200 non-null   object
#  4   CGPA             1200 non-null   float64
#  5   Attendance       1200 non-null   float64
# ...

# %%
# Target distribution
print(df['Employable'].value_counts())

plt.figure(figsize=(6,4))
sns.countplot(x='Employable', data=df)
plt.title('Employability Distribution')
plt.xlabel('Employable')
plt.ylabel('Number of Students')
plt.show()
# Out:
# Employable
# 1    691
# 0    509
# Name: count, dtype: int64

# %%
# Select numerical columns
numeric_df = df.select_dtypes(include=np.number)

# Correlation with target
correlation = numeric_df.corr()['Employable'].sort_values(ascending=False)

print("Correlation with Employability:")
display(correlation)
# Out:
# Correlation with Employability:
# Employable         1.000000
# Skill_Match        0.744529
# Resume_Match       0.729934
# Industry_Demand    0.711415
# Projects           0.667114
# ProblemSolving     0.659230
# DSA_Score          0.649516
# Internship         0.613863
# Resume_ATS         0.603063
# Certifications     0.586853
# JavaScript         0.584333
# OpenSource_PRs     0.582801
# Hackathons         0.535882
# Docker             0.502012
# NodeJS             0.500547
# HTML_CSS           0.494244
# React              0.492645
# Git                0.485198
# Communication      0.485149
# Aptitude           0.478795
# Python             0.457342
# Java               0.434198
# AWS                0.433127
# MachineLearning    0.414010
# SQL                0.412599
# C++                0.392744
# DataAnalysis       0.362652
# Linux              0.343083
# DeepLearning       0.296653
# Attendance         0.269111
# CGPA               0.259654
# Age               -0.040560
# ...

# %%
important_features = [
    'CGPA',
    'Attendance',
    'DSA_Score',
    'Aptitude',
    'Communication',
    'ProblemSolving',
    'Resume_ATS',
    'Resume_Match',
    'Skill_Match',
    'Industry_Demand'
]

for feature in important_features:
    plt.figure(figsize=(6,4))
    sns.boxplot(x='Employable', y=feature, data=df)
    plt.title(f'{feature} vs Employability')
    plt.show()

# %%
# Make a copy
data = df.copy()

# Remove Student_ID
data = data.drop('Student_ID', axis=1)

# Separate features and target
X = data.drop('Employable', axis=1)
y = data['Employable']

# Convert categorical columns into numerical values
X = pd.get_dummies(X, drop_first=True)

print("Features after encoding:")
print(X.shape)

display(X.head())
# Out:
# Features after encoding:
# (1200, 38)
#    Age  CGPA  Attendance  Python  Java  C++  SQL  JavaScript  HTML_CSS  React  \
# 0   20  8.80        92.9       1     1    1    1           1         1      1
# 1   20  9.11        97.6       1     1    1    1           1         1      1
# 2   22  8.93        89.1       1     1    1    1           1         1      0
# 3   22  9.52        99.5       1     1    1    1           1         1      0
# 4   23  8.88        95.9       1     1    1    1           0         1      0
#
#    ...  Resume_Match  Skill_Match  Missing_Skills  Industry_Demand  \
# 0  ...           100           99               3               99
# 1  ...            89           88               5               94
# 2  ...            74           62               6               68
# 3  ...            99           89               3               82
# 4  ...            85           80               6               83
#
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training samples:", X_train.shape[0])
print("Testing samples:", X_test.shape[0])
# Out:
# Training samples: 960
# Testing samples: 240

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("Scaling completed.")
# Out:
# Scaling completed.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix
)

log_model = LogisticRegression(max_iter=1000)

log_model.fit(X_train_scaled, y_train)

y_pred_log = log_model.predict(X_test_scaled)

print("Logistic Regression Accuracy:",
      accuracy_score(y_test, y_pred_log))

print("\nClassification Report:")
print(classification_report(y_test, y_pred_log))
# Out:
# Logistic Regression Accuracy: 0.8958333333333334
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88       102
#            1       0.92      0.89      0.91       138
#
#     accuracy                           0.90       240
#    macro avg       0.89      0.90      0.89       240
# weighted avg       0.90      0.90      0.90       240

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=200,
    random_state=42
)

rf_model.fit(X_train, y_train)

y_pred_rf = rf_model.predict(X_test)

print("Random Forest Accuracy:",
      accuracy_score(y_test, y_pred_rf))

print("\nClassification Report:")
print(classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 0.8791666666666667
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.86       102
#            1       0.89      0.91      0.90       138
#
#     accuracy                           0.88       240
#    macro avg       0.88      0.87      0.88       240
# weighted avg       0.88      0.88      0.88       240

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(
    random_state=42,
    max_depth=6
)

dt_model.fit(X_train, y_train)

y_pred_dt = dt_model.predict(X_test)

print("Decision Tree Accuracy:",
      accuracy_score(y_test, y_pred_dt))

print("\nClassification Report:")
print(classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.8875
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86       102
#            1       0.89      0.92      0.90       138
#
#     accuracy                           0.89       240
#    macro avg       0.89      0.88      0.88       240
# weighted avg       0.89      0.89      0.89       240

# %%
results = pd.DataFrame({
    'Model': [
        'Logistic Regression',
        'Decision Tree',
        'Random Forest'
    ],
    'Accuracy': [
        accuracy_score(y_test, y_pred_log),
        accuracy_score(y_test, y_pred_dt),
        accuracy_score(y_test, y_pred_rf)
    ]
})

results = results.sort_values(
    by='Accuracy',
    ascending=False
)

display(results)
# Out:
#                  Model  Accuracy
# 0  Logistic Regression  0.895833
# 1        Decision Tree  0.887500
# 2        Random Forest  0.879167

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x='Accuracy',
    y='Model',
    data=results
)

plt.xlim(0, 1)
plt.title('Model Accuracy Comparison')
plt.xlabel('Accuracy')
plt.ylabel('Model')
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred_rf)

plt.figure(figsize=(6,5))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=['Not Employable', 'Employable'],
    yticklabels=['Not Employable', 'Employable']
)

plt.title('Random Forest Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': rf_model.feature_importances_
})

feature_importance = feature_importance.sort_values(
    by='Importance',
    ascending=False
)

display(feature_importance.head(15))
# Out:
#             Feature  Importance
# 29      Skill_Match    0.169184
# 31  Industry_Demand    0.116743
# 28     Resume_Match    0.096239
# 30   Missing_Skills    0.096190
# 18         Projects    0.064703
# 23        DSA_Score    0.055258
# 26   ProblemSolving    0.054787
# 22   OpenSource_PRs    0.051608
# 19       Internship    0.034736
# 27       Resume_ATS    0.026924
# 25    Communication    0.025667
# 1              CGPA    0.022138
# 2        Attendance    0.021950
# 24         Aptitude    0.021838
# 20   Certifications    0.020799

# %%
top_features = feature_importance.head(15)

plt.figure(figsize=(10,7))

sns.barplot(
    x='Importance',
    y='Feature',
    data=top_features
)

plt.title('Top 15 Features Affecting Employability')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %%
# Create a sample student using the original feature structure
new_student = pd.DataFrame([{
    'Persona': 'Good',
    'Age': 21,
    'Gender': 'Female',
    'CGPA': 8.2,
    'Attendance': 90,
    'Python': 1,
    'Java': 1,
    'C++': 1,
    'SQL': 1,
    'JavaScript': 1,
    'HTML_CSS': 1,
    'React': 1,
    'NodeJS': 1,
    'Git': 1,
    'Docker': 0,
    'AWS': 1,
    'Linux': 1,
    'MachineLearning': 1,
    'DeepLearning': 0,
    'DataAnalysis': 1,
    'Projects': 5,
    'Internship': 1,
    'Certifications': 5,
    'Hackathons': 2,
    'OpenSource_PRs': 3,
    'DSA_Score': 80,
    'Aptitude': 82,
    'Communication': 85,
    'ProblemSolving': 88,
    'Resume_ATS': 90,
    'Resume_Match': 88,
    'Skill_Match': 90,
    'Missing_Skills': 3,
    'Industry_Demand': 90
}])

# Encode categorical columns
new_student = pd.get_dummies(
    new_student,
    drop_first=True
)

# Make sure columns match training data
new_student = new_student.reindex(
    columns=X.columns,
    fill_value=0
)

# Predict
prediction = rf_model.predict(new_student)

if prediction[0] == 1:
    print("Prediction: STUDENT IS EMPLOYABLE")
else:
    print("Prediction: STUDENT IS NOT EMPLOYABLE")
# Out:
# Prediction: STUDENT IS EMPLOYABLE

# %%
probability = rf_model.predict_proba(new_student)[0]

print("Probability of Not Employable:", round(probability[0] * 100, 2), "%")
print("Probability of Employable:", round(probability[1] * 100, 2), "%")
# Out:
# Probability of Not Employable: 6.0 %
# Probability of Employable: 94.0 %

# %%
import joblib

joblib.dump(rf_model, 'employability_random_forest.pkl')
joblib.dump(scaler, 'employability_scaler.pkl')

print("Models saved successfully!")
# Out:
# Models saved successfully!
